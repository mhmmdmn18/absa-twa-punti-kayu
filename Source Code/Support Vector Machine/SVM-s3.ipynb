# %%
import pickle
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Data
X = pickle.load(open('/content/drive/MyDrive/Skripsi/Library/text_s3.pkl', 'rb'))
y = pickle.load(open('/content/drive/MyDrive/Skripsi/Library/label_data.pkl', 'rb'))

# Convert labels to integers
LABEL2INDEX = {'none': 0, 'negatif': 1, 'netral': 2, 'positif': 3}
for aspect in y:
  y[aspect] = y[aspect].apply(lambda x: LABEL2INDEX[x])

# %%
# Initialize CountVectorizer
count_vect = CountVectorizer(analyzer='word', ngram_range=(1, 3), max_features=100000)

# Initialize model
model = SVC(kernel='linear', probability=True)

# Define Pipeline
original_pipeline = make_pipeline(count_vect, model)

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(cm, aspect, fold_idx):
    ax = sns.heatmap(cm, annot=True, fmt='g')
    ax.set_title(f"Confusion Matrix for {aspect} (Fold {fold_idx})")
    plt.show()

# Define aspects
aspects = ['daya_tarik', 'amenitas', 'aksesibilitas', 'citra', 'harga', 'sdm']

# Initialize performance metrics
total_acc = np.zeros(len(aspects))
total_f1 = np.zeros(len(aspects))

# Initialize KFold cross-validation
n_fold = 10
kf = KFold(n_splits = n_fold)

# 10-fold Cross Validation
for fold_idx, (train_index, test_index) in enumerate(kf.split(X), start=1):
    start_time = time.time()

    X_train, X_test = [X[i] for i in train_index], [X[i] for i in test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    fold_acc = []
    fold_f1 = []

    for i, aspect in enumerate(aspects):

        # Train model
        model_fit = original_pipeline.fit(X_train, y_train[i])
        y_pred = model_fit.predict(X_test)

        # Evaluate model
        cm = confusion_matrix(y_test[i], y_pred)
        plot_confusion_matrix(cm, aspect, fold_idx)
        print(classification_report(y_test[i], y_pred, zero_division='warn'))

        # Calculate metrics
        acc = accuracy_score(y_test[i], y_pred)
        f1 = f1_score(y_test[i], y_pred, average='weighted')
        fold_acc.append(acc)
        fold_f1.append(f1)
        total_acc[i] += acc
        total_f1[i] += f1

    # Print iteration time
    print(f"Iteration test time for fold {fold_idx}: {time.time() - start_time:.2f} seconds")

    # Print fold metrics
    print(f"Accuracy for fold {fold_idx}: {[round(a, 3) for a in fold_acc]}")
    print(f"F1 Score for fold {fold_idx}: {[round(f, 3) for f in fold_f1]}")

# Calculate and print average metrics
average_acc = total_acc / n_fold
average_f1 = total_f1 / n_fold
print("Final Average Accuracy: ", [round(a, 3) for a in average_acc])
print("Final Average F1 Score: ", [round(f, 3) for f in average_f1])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90       132
#            1       0.64      0.56      0.60        25
#            2       0.43      0.43      0.43        23
#            3       0.90      0.51      0.66        37
#
#     accuracy                           0.78       217
#    macro avg       0.70      0.62      0.65       217
# weighted avg       0.79      0.78      0.77       217
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       204
#            1       0.83      0.71      0.77         7
#            2       0.50      0.33      0.40         3
#            3       1.00      0.33      0.50         3
#
#     accuracy                           0.97       217
#    macro avg       0.83      0.59      0.66       217
# weighted avg       0.97      0.97      0.96       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       216
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       217
#    macro avg       0.50      0.50      0.50       217
# weighted avg       0.99      1.00      0.99       217
#               precision    recall  f1-score   support
#
#            0       0.47      0.60      0.53        40
#            1       0.44      0.47      0.46        34
#            2       0.43      0.30      0.36        43
#            3       0.79      0.79      0.79       100
#
#     accuracy                           0.61       217
#    macro avg       0.53      0.54      0.53       217
# weighted avg       0.61      0.61      0.60       217
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       203
#            1       0.33      0.67      0.44         3
#            2       0.00      0.00      0.00         9
#            3       1.00      0.50      0.67         2
#
#     accuracy                           0.94       217
#    macro avg       0.57      0.54      0.52       217
# weighted avg       0.91      0.94      0.92       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       215
#            1       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.99       217
#    macro avg       0.33      0.33      0.33       217
# weighted avg       0.98      0.99      0.99       217
#
# Iteration test time for fold 1: 23.76 seconds
# Accuracy for fold 1: [0.783, 0.968, 0.995, 0.608, 0.935, 0.991]
# F1 Score for fold 1: [0.772, 0.964, 0.993, 0.603, 0.921, 0.986]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90       155
#            1       0.81      0.55      0.65        31
#            2       0.08      0.14      0.11         7
#            3       0.81      0.54      0.65        24
#
#     accuracy                           0.82       217
#    macro avg       0.64      0.54      0.58       217
# weighted avg       0.83      0.82      0.81       217
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       200
#            1       0.86      0.46      0.60        13
#            3       0.00      0.00      0.00         4
#
#     accuracy                           0.94       217
#    macro avg       0.60      0.48      0.52       217
# weighted avg       0.92      0.94      0.93       217
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       213
#            3       1.00      0.25      0.40         4
#
#     accuracy                           0.99       217
#    macro avg       0.99      0.62      0.70       217
# weighted avg       0.99      0.99      0.98       217
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67        56
#            1       0.77      0.67      0.72        51
#            2       0.43      0.41      0.42        37
#            3       0.74      0.79      0.77        73
#
#     accuracy                           0.67       217
#    macro avg       0.65      0.64      0.64       217
# weighted avg       0.67      0.67      0.67       217
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       176
#            1       0.83      0.77      0.80        26
#            2       0.50      0.22      0.31         9
#            3       1.00      0.67      0.80         6
#
#     accuracy                           0.93       217
#    macro avg       0.82      0.66      0.72       217
# weighted avg       0.92      0.93      0.92       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       212
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.98       217
#    macro avg       0.49      0.50      0.49       217
# weighted avg       0.95      0.98      0.97       217
#
# Iteration test time for fold 2: 19.93 seconds
# Accuracy for fold 2: [0.816, 0.935, 0.986, 0.673, 0.926, 0.977]
# F1 Score for fold 2: [0.814, 0.926, 0.982, 0.671, 0.917, 0.966]
#               precision    recall  f1-score   support
#
#            0       0.50      0.98      0.66        81
#            1       0.81      0.65      0.72        34
#            2       0.50      0.08      0.14        63
#            3       0.77      0.44      0.56        39
#
#     accuracy                           0.57       217
#    macro avg       0.65      0.53      0.52       217
# weighted avg       0.60      0.57      0.50       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       203
#            1       0.71      0.45      0.56        11
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.95       217
#    macro avg       0.42      0.36      0.38       217
# weighted avg       0.94      0.95      0.94       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       212
#            1       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00         2
#
#     accuracy                           0.97       217
#    macro avg       0.33      0.33      0.33       217
# weighted avg       0.95      0.97      0.96       217
#               precision    recall  f1-score   support
#
#            0       0.52      0.38      0.44        68
#            1       0.59      0.49      0.54        53
#            2       0.29      0.47      0.36        40
#            3       0.67      0.68      0.67        56
#
#     accuracy                           0.50       217
#    macro avg       0.52      0.51      0.50       217
# weighted avg       0.53      0.50      0.51       217
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       201
#            1       0.82      1.00      0.90         9
#            2       1.00      0.17      0.29         6
#            3       1.00      1.00      1.00         1
#
#     accuracy                           0.97       217
#    macro avg       0.95      0.79      0.79       217
# weighted avg       0.97      0.97      0.96       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       212
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.98       217
#    macro avg       0.49      0.50      0.49       217
# weighted avg       0.95      0.98      0.97       217
#
# Iteration test time for fold 3: 20.01 seconds
# Accuracy for fold 3: [0.567, 0.949, 0.972, 0.502, 0.968, 0.977]
# F1 Score for fold 3: [0.5, 0.941, 0.963, 0.509, 0.96, 0.966]
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.91       144
#            1       0.81      0.58      0.68        36
#            2       0.64      0.29      0.40        24
#            3       0.69      0.69      0.69        13
#
#     accuracy                           0.82       217
#    macro avg       0.75      0.64      0.67       217
# weighted avg       0.81      0.82      0.80       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       203
#            1       0.67      0.50      0.57        12
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.95       217
#    macro avg       0.41      0.37      0.39       217
# weighted avg       0.94      0.95      0.95       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       210
#            2       0.00      0.00      0.00         2
#            3       1.00      0.20      0.33         5
#
#     accuracy                           0.97       217
#    macro avg       0.66      0.40      0.44       217
# weighted avg       0.96      0.97      0.96       217
#               precision    recall  f1-score   support
#
#            0       0.47      0.61      0.54        31
#            1       0.89      0.83      0.86        93
#            2       0.61      0.65      0.63        48
#            3       0.72      0.62      0.67        45
#
#     accuracy                           0.71       217
#    macro avg       0.67      0.68      0.67       217
# weighted avg       0.73      0.71      0.72       217
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       196
#            1       1.00      0.77      0.87        13
#            2       1.00      0.50      0.67         4
#            3       1.00      0.50      0.67         4
#
#     accuracy                           0.97       217
#    macro avg       0.99      0.69      0.80       217
# weighted avg       0.97      0.97      0.96       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       215
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       217
#    macro avg       0.50      0.50      0.50       217
# weighted avg       0.98      0.99      0.99       217
#
# Iteration test time for fold 4: 20.80 seconds
# Accuracy for fold 4: [0.82, 0.954, 0.972, 0.714, 0.968, 0.991]
# F1 Score for fold 4: [0.8, 0.947, 0.962, 0.72, 0.964, 0.986]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       176
#            1       0.67      0.67      0.67        12
#            2       0.50      0.37      0.42        19
#            3       0.58      0.70      0.64        10
#
#     accuracy                           0.88       217
#    macro avg       0.67      0.68      0.67       217
# weighted avg       0.88      0.88      0.88       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       205
#            1       0.60      0.33      0.43         9
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         2
#
#     accuracy                           0.95       217
#    macro avg       0.39      0.33      0.35       217
# weighted avg       0.93      0.95      0.94       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       216
#            1       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         0
#
#     accuracy                           0.99       217
#    macro avg       0.33      0.33      0.33       217
# weighted avg       0.99      0.99      0.99       217
#               precision    recall  f1-score   support
#
#            0       0.53      0.84      0.65        43
#            1       0.67      0.63      0.65        38
#            2       0.65      0.44      0.52        55
#            3       0.82      0.77      0.79        81
#
#     accuracy                           0.67       217
#    macro avg       0.67      0.67      0.65       217
# weighted avg       0.69      0.67      0.67       217
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       190
#            1       0.94      0.79      0.86        19
#            2       0.50      0.40      0.44         5
#            3       1.00      0.33      0.50         3
#
#     accuracy                           0.96       217
#    macro avg       0.85      0.63      0.70       217
# weighted avg       0.96      0.96      0.95       217
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       215
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       217
#    macro avg       0.50      0.50      0.50       217
# weighted avg       0.98      0.99      0.99       217
#
# Iteration test time for fold 5: 20.42 seconds
# Accuracy for fold 5: [0.885, 0.949, 0.991, 0.673, 0.959, 0.991]
# F1 Score for fold 5: [0.88, 0.94, 0.991, 0.669, 0.954, 0.986]
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       150
#            1       0.58      0.56      0.57        27
#            2       0.08      0.09      0.08        11
#            3       0.73      0.68      0.70        28
#
#     accuracy                           0.79       216
#    macro avg       0.57      0.56      0.56       216
# weighted avg       0.80      0.79      0.79       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       194
#            1       0.57      0.33      0.42        12
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         8
#
#     accuracy                           0.91       216
#    macro avg       0.37      0.33      0.35       216
# weighted avg       0.87      0.91      0.89       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       208
#            2       0.00      0.00      0.00         2
#            3       1.00      0.33      0.50         6
#
#     accuracy                           0.97       216
#    macro avg       0.66      0.44      0.50       216
# weighted avg       0.96      0.97      0.96       216
#               precision    recall  f1-score   support
#
#            0       0.42      0.62      0.50        29
#            1       0.72      0.72      0.72        64
#            2       0.45      0.46      0.45        46
#            3       0.84      0.68      0.75        77
#
#     accuracy                           0.63       216
#    macro avg       0.61      0.62      0.60       216
# weighted avg       0.66      0.63      0.64       216
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       195
#            1       0.75      0.38      0.50         8
#            2       0.36      0.67      0.47         6
#            3       0.75      0.43      0.55         7
#
#     accuracy                           0.93       216
#    macro avg       0.71      0.61      0.62       216
# weighted avg       0.94      0.93      0.93       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       214
#            1       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.99       216
#    macro avg       0.33      0.33      0.33       216
# weighted avg       0.98      0.99      0.99       216
#
# Iteration test time for fold 6: 19.90 seconds
# Accuracy for fold 6: [0.792, 0.912, 0.972, 0.634, 0.931, 0.991]
# F1 Score for fold 6: [0.794, 0.886, 0.963, 0.643, 0.929, 0.986]
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       150
#            1       0.65      0.46      0.54        24
#            2       0.27      0.43      0.33        14
#            3       0.80      0.57      0.67        28
#
#     accuracy                           0.80       216
#    macro avg       0.65      0.60      0.61       216
# weighted avg       0.81      0.80      0.80       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97       197
#            1       0.80      0.40      0.53        10
#            2       0.00      0.00      0.00         4
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.93       216
#    macro avg       0.43      0.35      0.37       216
# weighted avg       0.89      0.93      0.91       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       209
#            2       0.00      0.00      0.00         2
#            3       0.67      0.40      0.50         5
#
#     accuracy                           0.98       216
#    macro avg       0.55      0.47      0.50       216
# weighted avg       0.96      0.98      0.97       216
#               precision    recall  f1-score   support
#
#            0       0.41      0.70      0.52        27
#            1       0.53      0.54      0.53        39
#            2       0.68      0.42      0.52        59
#            3       0.84      0.86      0.85        91
#
#     accuracy                           0.66       216
#    macro avg       0.61      0.63      0.61       216
# weighted avg       0.68      0.66      0.66       216
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       198
#            1       1.00      0.43      0.60        14
#            2       0.50      0.33      0.40         3
#            3       0.33      1.00      0.50         1
#
#     accuracy                           0.95       216
#    macro avg       0.70      0.69      0.62       216
# weighted avg       0.95      0.95      0.94       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       213
#            1       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.99       216
#    macro avg       0.33      0.33      0.33       216
# weighted avg       0.97      0.99      0.98       216
#
# Iteration test time for fold 7: 20.45 seconds
# Accuracy for fold 7: [0.796, 0.931, 0.977, 0.662, 0.949, 0.986]
# F1 Score for fold 7: [0.796, 0.905, 0.97, 0.661, 0.943, 0.979]
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       156
#            1       0.63      0.75      0.69        16
#            2       0.23      0.20      0.21        15
#            3       0.84      0.72      0.78        29
#
#     accuracy                           0.84       216
#    macro avg       0.66      0.65      0.65       216
# weighted avg       0.84      0.84      0.84       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       196
#            1       0.71      0.36      0.48        14
#            3       0.00      0.00      0.00         6
#
#     accuracy                           0.92       216
#    macro avg       0.55      0.45      0.48       216
# weighted avg       0.89      0.92      0.90       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       208
#            1       0.00      0.00      0.00         1
#            3       1.00      0.29      0.44         7
#
#     accuracy                           0.97       216
#    macro avg       0.66      0.43      0.48       216
# weighted avg       0.97      0.97      0.96       216
#               precision    recall  f1-score   support
#
#            0       0.31      0.57      0.40        14
#            1       0.62      0.80      0.70        25
#            2       0.69      0.50      0.58        86
#            3       0.69      0.73      0.71        91
#
#     accuracy                           0.63       216
#    macro avg       0.58      0.65      0.60       216
# weighted avg       0.66      0.63      0.64       216
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       188
#            1       0.89      0.67      0.76        12
#            2       0.67      0.67      0.67         3
#            3       1.00      0.46      0.63        13
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.70      0.76       216
# weighted avg       0.95      0.94      0.94       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       215
#            3       0.00      0.00      0.00         1
#
#     accuracy                           1.00       216
#    macro avg       0.50      0.50      0.50       216
# weighted avg       0.99      1.00      0.99       216
#
# Iteration test time for fold 8: 20.29 seconds
# Accuracy for fold 8: [0.843, 0.921, 0.972, 0.634, 0.944, 0.995]
# F1 Score for fold 8: [0.84, 0.9, 0.964, 0.636, 0.937, 0.993]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       159
#            1       0.73      0.61      0.67        18
#            2       0.20      0.09      0.13        11
#            3       0.70      0.68      0.69        28
#
#     accuracy                           0.87       216
#    macro avg       0.64      0.59      0.61       216
# weighted avg       0.84      0.87      0.85       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       197
#            1       0.67      0.31      0.42        13
#            2       0.00      0.00      0.00         2
#            3       0.50      0.25      0.33         4
#
#     accuracy                           0.92       216
#    macro avg       0.52      0.39      0.43       216
# weighted avg       0.90      0.92      0.91       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       208
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         1
#            3       0.50      0.17      0.25         6
#
#     accuracy                           0.96       216
#    macro avg       0.37      0.29      0.31       216
# weighted avg       0.95      0.96      0.95       216
#               precision    recall  f1-score   support
#
#            0       0.10      0.25      0.14         4
#            1       0.61      0.74      0.67        19
#            2       0.40      0.57      0.47        40
#            3       0.91      0.75      0.82       153
#
#     accuracy                           0.70       216
#    macro avg       0.50      0.58      0.52       216
# weighted avg       0.77      0.70      0.73       216
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       197
#            1       0.50      0.17      0.25         6
#            2       0.62      0.50      0.56        10
#            3       1.00      0.33      0.50         3
#
#     accuracy                           0.94       216
#    macro avg       0.77      0.50      0.57       216
# weighted avg       0.93      0.94      0.93       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       215
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       216
#    macro avg       0.50      0.50      0.50       216
# weighted avg       0.99      1.00      0.99       216
#
# Iteration test time for fold 9: 20.25 seconds
# Accuracy for fold 9: [0.866, 0.921, 0.963, 0.704, 0.94, 0.995]
# F1 Score for fold 9: [0.852, 0.905, 0.952, 0.729, 0.929, 0.993]
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90       143
#            1       0.61      0.44      0.51        32
#            2       0.33      0.24      0.28        21
#            3       0.44      0.35      0.39        20
#
#     accuracy                           0.76       216
#    macro avg       0.56      0.50      0.52       216
# weighted avg       0.73      0.76      0.74       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       203
#            1       0.40      0.29      0.33         7
#            2       0.00      0.00      0.00         3
#            3       0.50      0.33      0.40         3
#
#     accuracy                           0.95       216
#    macro avg       0.47      0.40      0.43       216
# weighted avg       0.93      0.95      0.94       216
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       211
#            1       0.00      0.00      0.00         1
#            3       0.75      0.75      0.75         4
#
#     accuracy                           0.99       216
#    macro avg       0.58      0.58      0.58       216
# weighted avg       0.98      0.99      0.98       216
#               precision    recall  f1-score   support
#
#            0       0.63      0.83      0.72        52
#            1       0.77      0.69      0.73        48
#            2       0.72      0.58      0.64        48
#            3       0.82      0.79      0.81        68
#
#     accuracy                           0.73       216
#    macro avg       0.73      0.72      0.72       216
# weighted avg       0.74      0.73      0.73       216
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       174
#            1       0.90      0.83      0.86        23
#            2       0.67      0.31      0.42        13
#            3       0.80      0.67      0.73         6
#
#     accuracy                           0.93       216
#    macro avg       0.83      0.70      0.75       216
# weighted avg       0.92      0.93      0.92       216
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       215
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       216
#    macro avg       0.50      0.50      0.50       216
# weighted avg       0.99      1.00      0.99       216
#
# Iteration test time for fold 10: 19.89 seconds
# Accuracy for fold 10: [0.759, 0.949, 0.986, 0.731, 0.931, 0.995]
# F1 Score for fold 10: [0.738, 0.938, 0.984, 0.73, 0.921, 0.993]
# Final Average Accuracy:  [0.793, 0.939, 0.979, 0.654, 0.945, 0.989]
# Final Average F1 Score:  [0.779, 0.925, 0.972, 0.657, 0.937, 0.983]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
